# %%
G = Graph({0: [1, 11, 14],
           1: [2, 15],
           2: [3, 16],
           3: [4, 7],
           4: [5, 9],
           5: [6, 17],
           6: [7, 15],
           7: [8],
           8: [9, 17],
           9: [10],
           10: [11, 16],
           11: [12],
           12: [13, 17],
           13: [14, 15],
           14: [16]})
G
# Out:
# Graph on 18 vertices

# %%
G.automorphism_group()
# Out:
# Permutation Group with generators [(1,11)(2,10)(3,9)(6,17)(7,8)(12,15), (1,11)(2,12)(3,17)(4,5)(6,9)(7,8)(10,15)(13,16), (0,14)(1,16)(4,7)(5,8)(6,9)(10,15)(11,13)]

# %%
G.characteristic_polynomial().factor()
# Out:
# (x - 3) * (x + 1) * (x + 2) * (x - 1)^3 * (x^4 + x^3 - 7*x^2 - 5*x + 6) * (x^4 + x^3 - 5*x^2 - 3*x + 4)^2
